# %% [markdown]
# ### Imports and initializations

# %%
import pandas as pd
import matplotlib.pyplot as plt

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12
# Out:
# /home/navar/anaconda3/envs/fogocruzado/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/navar/anaconda3/envs/fogocruzado/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
data_path = '../data/raw/Amostra da base - Sheet33.csv'

data = pd.read_csv(data_path)

# %%
data.head()
# Out:
#     IDv2                                           ENDEREÇO      LATITUDE  \
# 0   8758                  Maré, Rio de Janeiro - RJ, Brasil  -22.85749626
# 1  10431  R. Alice - Laranjeiras, Rio de Janeiro - RJ, B...  -22.93537730
# 2  10430            Areia Branca, Belford Roxo - RJ, Brasil  -22.74860040
# 3  10429                   Austin, Nova Iguaçu - RJ, Brasil  -22.72017380
# 4  10545          Jardim Catarina, São Gonçalo - RJ, Brasil  -22.79216690
#
#       LONGITUDE                 DATA  PRESENÇA POLICIAL MORTOS FERIDOS  \
# 0  -43.24301529  09/01/2018 15:57:00                  0    Não     Não
# 1  -43.19463100  19/01/2018 20:54:00                  0    Não     Não
# 2  -43.41062760  19/01/2018 18:37:00                  0    Não     Não
# 3  -43.52463610  19/01/2018 16:20:00                  0    Não     Não
# 4  -42.99979770  22/01/2018 00:00:00                  1    Não     Não
#
#    MORTOS CIVIS  MORTOS POLICIAIS   ...     MÊS   ANO      HORA  LOGRADOURO  \
# 0             0                 0   ...       1  2018  15:57:00         NaN
# 1             0                 0   ...       1  2018  20:54:00   Rua Alice
# 2             0                 0   ...       1  2018  18:37:00         NaN
# 3             0                 0   ...       1  2018  16:20:00         NaN
# 4             0                 0   ...       1  2018   0:00:00         NaN
#
#             BAIRRO       MUNICÍPIO        LOCALIDADE UPP ÁREA DA UPP Semestre
# 0             Maré  Rio de Janeiro  Complexo da Maré   0         NaN   2018.1
# 1      Laranjeiras  Rio de Janeiro               NaN   0         NaN   2018.1
# 2     Areia Branca    Belford Roxo               NaN   0         NaN   2018.1
# 3           Austin     Nova Iguaçu               NaN   0         NaN   2018.1
# 4  Jardim Catarina     São Gonçalo               NaN   0         NaN   2018.1
#
# [5 rows x 24 columns]

# %%
data.describe()
# Out:
#                IDv2  PRESENÇA POLICIAL  MORTOS CIVIS  MORTOS POLICIAIS  \
# count   4668.000000        4668.000000   4668.000000       4668.000000
# mean   12873.951585           0.160026      0.156170          0.012211
# std     2030.754693           0.366669      0.525981          0.109838
# min     8614.000000           0.000000      0.000000          0.000000
# 25%    11340.750000           0.000000      0.000000          0.000000
# 50%    12915.500000           0.000000      0.000000          0.000000
# 75%    14582.250000           0.000000      0.000000          0.000000
# max    16331.000000           1.000000      8.000000          1.000000
#
#        FERIDOS CIVIS  FERIDOS POLICIAIS          DIA          MÊS     ANO  \
# count    4668.000000        4668.000000  4668.000000  4668.000000  4668.0
# mean        0.113753           0.029563    15.469152     3.645887  2018.0
# std         0.445100           0.200663     8.850623     1.693941     0.0
# min         0.000000           0.000000     1.000000     1.000000  2018.0
# 25%         0.000000           0.000000     8.000000     2.000000  2018.0
# 50%         0.000000           0.000000    16.000000     4.000000  2018.0
# 75%         0.000000           0.000000    23.000000     5.000000  2018.0
# max         5.000000           5.000000    31.000000     6.000000  2018.0
#
#                UPP      Semestre
# count  4668.000000  4.668000e+03
# mean      0.227292  2.018100e+03
# std       0.419128  2.273980e-13
# min       0.000000  2.018100e+03
# 25%       0.000000  2.018100e+03
# 50%       0.000000  2.018100e+03
# 75%       0.000000  2.018100e+03
# max       1.000000  2.018100e+03

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4668 entries, 0 to 4667
# Data columns (total 24 columns):
# IDv2                 4668 non-null int64
# ENDEREÇO             4668 non-null object
# LATITUDE             4668 non-null object
# LONGITUDE            4668 non-null object
# DATA                 4668 non-null object
# PRESENÇA POLICIAL    4668 non-null int64
# MORTOS               4668 non-null object
# FERIDOS              4668 non-null object
# MORTOS CIVIS         4668 non-null int64
# MORTOS POLICIAIS     4668 non-null int64
# FERIDOS CIVIS        4668 non-null int64
# FERIDOS POLICIAIS    4668 non-null int64
# FONTE                4668 non-null object
# DIA                  4668 non-null int64
# MÊS                  4668 non-null int64
# ANO                  4668 non-null int64
# HORA                 4668 non-null object
# LOGRADOURO           2443 non-null object
# BAIRRO               4650 non-null object
# MUNICÍPIO            4668 non-null object
# LOCALIDADE           2746 non-null object
# UPP                  4668 non-null int64
# ÁREA DA UPP          1115 non-null object
# Semestre             4668 non-null float64
# dtypes: float64(1), int64(10), object(13)
# memory usage: 875.3+ KB

# %%
data['MORTOS'].value_counts()
# Out:
# Não    4080
# Sim     588
# Name: MORTOS, dtype: int64

# %%
data['FERIDOS'].value_counts()
# Out:
# Não    4194
# Sim     474
# Name: FERIDOS, dtype: int64

# %% [markdown]
# There is has to be a precaution while looking to "MORTOS" and "FERIDOS" inputs. For example, not all of the negatives repors of "MORTOS" mean they were harmed and most of the negative reports of "FERIDOS" are just occurences of gunfire.

# %%
data.hist(bins=100, figsize=(18,10))
plt.show()

# %% [markdown]
# These are general information. Let's take a look at them carefully. What is the period of the record?

# %% [markdown]
# Thankfully the datetime filed has been split before into three fields, "DIA", "MÊS" and "ANO".

# %%
print("This data is from {}/{}/{} to {}/{}/{}".format(min(data['DIA']), min(data['MÊS']), min(data['ANO']),
                                                      max(data['DIA']), max(data['MÊS']), max(data['ANO'])))
# Out:
# This data is from 1/1/2018 to 31/6/2018

# %% [markdown]
# dd/mm/yyyy format

# %% [markdown]
# ## Occurences overview

# %%
data['MÊS'].value_counts()

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
ax = data['MÊS'].hist(bins=15, figsize=(8,5))
plt.xlabel('Month')
plt.ylabel('Occurrences')
plt.show()

# %% [markdown]
# The worst month during this period os May, followed by June, March, April, January and February. Let's take a look the which time during the day is the worst.

# %%
data['HORA'].value_counts()
# Out:
# 0:00:00     327
# 15:00:00     83
# 8:00:00      71
# 22:00:00     61
# 20:00:00     43
# 9:00:00      39
# 6:00:00      35
# 21:00:00     31
# 17:00:00     31
# 10:00:00     28
# 7:00:00      27
# 19:00:00     20
# 3:00:00      20
# 18:00:00     19
# 13:00:00     18
# 9:30:00      16
# 20:40:00     16
# 8:30:00      16
# 14:00:00     15
# 6:30:00      15
# 19:20:00     14
# 16:00:00     14
# 23:30:00     13
# 11:00:00     13
# 12:00:00     13
# 0:30:00      13
# 23:00:00     13
# 22:30:00     13
# 5:30:00      12
# 2:00:00      12
#            ...
# 4:24:00       1
# 0:52          1
# 23:25         1
# 11:01         1
# 7:38:00       1
# 16:22:00      1
# 8:23          1
# 7:42          1
# 1:09          1
# 0:58:00       1
# 14:57:00      1
# 17:33:00      1
# 8:59:00       1
# 13:14:00      1
# 21:59         1
# 8:10:00       1
# 23:30:35      1
# 5:14:00       1
# 10:20         1
# 18:07         1
# 0:59:00       1
# 6:44:00       1
# 2:01:00       1
# 13:56:00      1
# 9:39:00       1
# 22:08         1
# 9:01          1
# 14:16:00      1
# 12:04:33      1
# 2:14:00       1
# Name: HORA, Length: 1504, dtype: int64

# %% [markdown]
# Need to strip time only by hour.

# %%
import time

hour_buffer = []
for x in data['HORA']:
    if len(x) >= 7:
        time_obj = time.strptime(x, '%H:%M:%S')
        hour_buffer.append(time_obj.tm_hour)
    else:
        time_obj = time.strptime(x, '%H:%M')
        hour_buffer.append(time_obj.tm_hour)
            
data['HOUR_ONLY'] = hour_buffer

# %%
data['HOUR_ONLY'].hist(bins=50, figsize=(8,5))
plt.show()

# %%
data['HOUR_ONLY'].describe()
# Out:
# count    4668.000000
# mean       12.442374
# std         7.445416
# min         0.000000
# 25%         7.000000
# 50%        13.000000
# 75%        19.000000
# max        23.000000
# Name: HOUR_ONLY, dtype: float64

# %% [markdown]
# 75% of the reports are made past 19 p.m. :( Too bad going out at night in such a beatiful city. Let's see which neighborhood we should avoid.

# %%
len(data['BAIRRO'].unique())
# Out:
# 535

# %% [markdown]
# There are to many to look into it. Let' pick the worst 10.

# %%
# top10 = data.groupby('BAIRRO').BAIRRO.agg(['count']).sort_values(by='count', ascending=False).iloc[0:10]
bairros = data.groupby('BAIRRO').BAIRRO.agg(['count']).sort_values(by='count', ascending=False)
top10 = bairros.iloc[0:10]
top10.plot(kind='bar')
plt.show()

# %% [markdown]
# Impressive! I had a feeling Rocinha would have more occurences than other by far. Turns out Praça Seca is the worst.

# %%
bairros['count'] = (bairros['count']/bairros['count'].sum())*100

# %%
bairros.iloc[0:10]
# Out:
#                        count
# BAIRRO
# Praça Seca          4.344086
# Cidade de Deus      3.354839
# Vila Kennedy        2.817204
# Complexo do Alemão  2.430108
# Rocinha             2.387097
# Centro              2.172043
# Tijuca              1.956989
# Realengo            1.698925
# Pavuna              1.569892
# Taquara             1.440860

# %%
bairros.iloc[0:10].sum()
# Out:
# count    24.172043
# dtype: float64

# %% [markdown]
# So, Praça Seca accounts for 4.34% of all occurences, while Rocinha for 2.4%. And, 10 neighborhoods out of 535, accounts for almost a quarter (24.17%) of all reports. That clearly indicates the violence tend to happens in the same regions because of "favelas", drugs, etc.

# %% [markdown]
# The latitude and longitude

# %%
from src.data import Cleaning

clean_01 = Cleaning.RemoveOutliers_lat_long()
clean_02 = Cleaning.String2Float_lat_long()

data = clean_01.fit_transform(data)
data = clean_02.fit_transform(data)

# %%
import matplotlib.image as mpimg
rio_img = mpimg.imread('../figs/Rio_de_janeiro.png')
ax = data.plot(kind='scatter', x='LONGITUDE', y= 'LATITUDE', figsize=(15,10), alpha = 0.5, s=50)
plt.imshow(rio_img, extent=[-44.93, -40.81, -23.43, -20.72], alpha=0.5, cmap=plt.get_cmap("jet"))

# %%
u1 = pd.DataFrame(LONG)
u2 = pd.DataFrame(LAT)
idx = (u1 <= -43) & (u2 <= -22.75)

rio_city_img = mpimg.imread('../figs/RJ.png')
plt.figure(figsize=(18,10))
plt.imshow(rio_city_img, extent=[-43.906927, -42.987857, -23.081902, -22.736000], alpha=0.5, cmap=plt.get_cmap("jet"))
plt.scatter(u1[idx], u2[idx], c='r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-37423eff514a> in <module>()
# ----> 1 u1 = pd.DataFrame(LONG)
#       2 u2 = pd.DataFrame(LAT)
#       3 idx = (u1 <= -43) & (u2 <= -22.75)
#       4
#       5 rio_city_img = mpimg.imread('../figs/RJ.png')
#
# NameError: name 'LONG' is not defined

# %% [markdown]
# # Create a transform for data cleaning

# %%
from src.data import Cleaning

clean_01 = Cleaning.RemoveOutliers_lat_long()
clean_02 = Cleaning.String2Float_lat_long()

data_2 = clean_01.fit_transform(data)
data_3 = clean_02.fit_transform(data_2)

# %%
u1 = data_3['LONGITUDE']
u2 = data_3['LATITUDE']
idx = (u1 <= -43) & (u2 <= -22.75)

rio_city_img = mpimg.imread('../figs/RJ.png')
plt.figure(figsize=(18,10))
plt.imshow(rio_city_img, extent=[-43.906927, -42.987857, -23.081902, -22.736000], alpha=0.5, cmap=plt.get_cmap("jet"))
plt.scatter(u1[idx], u2[idx], c='r')
